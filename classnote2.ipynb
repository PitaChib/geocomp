# %%
my_list = [1,2,3,4,5]
print (my_list)
print(my_list[0])
# Out:
# [1, 2, 3, 4, 5]
# 1

# %%
#for loop
for element in my_list:
    print ("element =", element)#the loop takes the commend, and does it down th eline

for gummy_bear in my_list:
    print ("my list has the value = ", gummy_bear)
    print("this is another line")
print ("when will this run")#no longer inside the loop
print(gummy_bear)
#adding value to the lisT:
my_list.append("9")

## dictionary : unordered, no location 
mydictionary = { 'y': 44.9, 'x': -93.2, 'v': 10}
print (mydictionary.keys())
print (mydictionary ['x'])
# Out:
# element = 1
# element = 2
# element = 3
# element = 4
# element = 5
# element = 9
# element = 9
# element = 9
# element = 9
# element = 9
# element = 9
# element = 9
# element = 9
# my list has the value =  1
# this is another line
# my list has the value =  2
# this is another line
# my list has the value =  3
# this is another line
# my list has the value =  4
# this is another line
# my list has the value =  5
# this is another line
# my list has the value =  9
# this is another line
# my list has the value =  9
# this is another line
# my list has the value =  9
# this is another line
# my list has the value =  9
# this is another line
# my list has the value =  9
# this is another line
# my list has the value =  9
# this is another line
# my list has the value =  9
# this is another line
# my list has the value =  9
# this is another line
# when will this run
# 9
# dict_keys(['y', 'x', 'v'])
# -93.2

# %%
dic2 = {'loc1':
            {'y':44.9,'x': -93.2},
        'loc2':
            {'y':1,'x':0.48}
        }
dic2.keys()
print ("loc1", dic2['loc1'])
#print("I want the value of x and itis: ", dic2['x'])#wouldn't work, since it's not directly searchable
manual_loc1 = dic2['loc1']
print ("manual loc1 = ",manual_loc1)
x = manual_loc1['x']
x
#shprt
print("valaue of x :", dic2['loc1']['x'])
# Out:
# loc1 {'y': 44.9, 'x': -93.2}
# manual loc1 =  {'y': 44.9, 'x': -93.2}
# valaue of x : -93.2

# %%
#JSON
nice = "It is nice to meet you"
great = "It is great to meet you"

name_list = ["Bob", "Gina","Jose","Layla","Li"]
def greet(name):
    if name == "Li":
        print(great, name)
    else:
        print (nice,name)
greet ("Li")
greet("Bob")
# Out:
# It is great to meet you Li
# It is nice to meet you Bob

# %% [markdown]
# ### Feb 19 // Rasters

# %%
raster=[[1,2,1,2],
        [3,4,3,4],
        [1,2,1,2],
        [3,4,3,4] ]

# %%
for row in raster:
    print("row=", row)

#oth element
for row in raster:
    print("row =", row)
    print ("0th element, option a", raster [0])#always getting the first row 
    print("0th element, option b", row[0]) #<-- what we want
    print("0th element, option c", [0]) #printing out the list containing variable 0.
# Out:
# row= [1, 2, 1, 2]
# row= [3, 4, 3, 4]
# row= [1, 2, 1, 2]
# row= [3, 4, 3, 4]
# row = [1, 2, 1, 2]
# 0th element, option a [1, 2, 1, 2]
# 0th element, option b 1
# 0th element, option c [0]
# row = [3, 4, 3, 4]
# 0th element, option a [1, 2, 1, 2]
# 0th element, option b 3
# 0th element, option c [0]
# row = [1, 2, 1, 2]
# 0th element, option a [1, 2, 1, 2]
# 0th element, option b 1
# 0th element, option c [0]
# row = [3, 4, 3, 4]
# 0th element, option a [1, 2, 1, 2]
# 0th element, option b 3
# 0th element, option c [0]

# %%
for row in raster: 
    print("row =", row)
    for element in row: 
        print("element =", element)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 for row in raster:
#       2     print("row =", row)
#       3     for element in row:
#
# NameError: name 'raster' is not defined

# %%
## range()
list (range(5))
list(range(5,10))
# Out:
# [5, 6, 7, 8, 9]

# %%
for r in range(4): #what about we don't know the size? 
    for c in range (4):
        print("raster[",r,"][",c,"] =", raster [r][c])
# Out:
# raster[ 0 ][ 0 ] = 1
# raster[ 0 ][ 1 ] = 2
# raster[ 0 ][ 2 ] = 1
# raster[ 0 ][ 3 ] = 2
# raster[ 1 ][ 0 ] = 3
# raster[ 1 ][ 1 ] = 4
# raster[ 1 ][ 2 ] = 3
# raster[ 1 ][ 3 ] = 4
# raster[ 2 ][ 0 ] = 1
# raster[ 2 ][ 1 ] = 2
# raster[ 2 ][ 2 ] = 1
# raster[ 2 ][ 3 ] = 2
# raster[ 3 ][ 0 ] = 3
# raster[ 3 ][ 1 ] = 4
# raster[ 3 ][ 2 ] = 3
# raster[ 3 ][ 3 ] = 4
# raster[ 0 ][ 0 ] = 1
# raster[ 0 ][ 1 ] = 2
# raster[ 0 ][ 2 ] = 1
# raster[ 0 ][ 3 ] = 2
# raster[ 1 ][ 0 ] = 3
# raster[ 1 ][ 1 ] = 4
# raster[ 1 ][ 2 ] = 3
# raster[ 1 ][ 3 ] = 4
# raster[ 2 ][ 0 ] = 1
# raster[ 2 ][ 1 ] = 2
# raster[ 2 ][ 2 ] = 1
# raster[ 2 ][ 3 ] = 2
# raster[ 3 ][ 0 ] = 3
# raster[ 3 ][ 1 ] = 4
# raster[ 3 ][ 2 ] = 3
# raster[ 3 ][ 3 ] = 4

# %%
global_pop =[0]
for r in range(len(raster)):
    for c in range(len(raster[0])):
        global_pop.append(c)
        print("raster[",r,"][",c,"] =", raster [r][c])
print(sum(global_pop))
##correct 
global_sum = 0
for r in range(len(raster)):
    for c in range(len(raster[0])):
        print("raster[",r,"][",c,"] =", raster [r][c])
        global_sum += raster[r][c]
print(global_sum)
# Out:
# raster[ 0 ][ 0 ] = 1
# raster[ 0 ][ 1 ] = 2
# raster[ 0 ][ 2 ] = 1
# raster[ 0 ][ 3 ] = 2
# raster[ 1 ][ 0 ] = 3
# raster[ 1 ][ 1 ] = 4
# raster[ 1 ][ 2 ] = 3
# raster[ 1 ][ 3 ] = 4
# raster[ 2 ][ 0 ] = 1
# raster[ 2 ][ 1 ] = 2
# raster[ 2 ][ 2 ] = 1
# raster[ 2 ][ 3 ] = 2
# raster[ 3 ][ 0 ] = 3
# raster[ 3 ][ 1 ] = 4
# raster[ 3 ][ 2 ] = 3
# raster[ 3 ][ 3 ] = 4
# 24
# raster[ 0 ][ 0 ] = 1
# raster[ 0 ][ 1 ] = 2
# raster[ 0 ][ 2 ] = 1
# raster[ 0 ][ 3 ] = 2
# raster[ 1 ][ 0 ] = 3
# raster[ 1 ][ 1 ] = 4
# raster[ 1 ][ 2 ] = 3
# raster[ 1 ][ 3 ] = 4
# raster[ 2 ][ 0 ] = 1
# raster[ 2 ][ 1 ] = 2
# raster[ 2 ][ 2 ] = 1
# raster[ 2 ][ 3 ] = 2
# raster[ 3 ][ 0 ] = 3
# raster[ 3 ][ 1 ] = 4
# raster[ 3 ][ 2 ] = 3
# raster[ 3 ][ 3 ] = 4
# 40

# %%
global_sum = 0
for r in range(len(raster)):
    for c in range(len(raster[0])):
        # raster[r][c]*=2
        print("raster[",r,"][",c,"] =", raster [r][c]*2)
        global_sum += raster[r][c]*2
print(global_sum)
# Out:
# raster[ 0 ][ 0 ] = 2
# raster[ 0 ][ 1 ] = 4
# raster[ 0 ][ 2 ] = 2
# raster[ 0 ][ 3 ] = 4
# raster[ 1 ][ 0 ] = 6
# raster[ 1 ][ 1 ] = 8
# raster[ 1 ][ 2 ] = 6
# raster[ 1 ][ 3 ] = 8
# raster[ 2 ][ 0 ] = 2
# raster[ 2 ][ 1 ] = 4
# raster[ 2 ][ 2 ] = 2
# raster[ 2 ][ 3 ] = 4
# raster[ 3 ][ 0 ] = 6
# raster[ 3 ][ 1 ] = 8
# raster[ 3 ][ 2 ] = 6
# raster[ 3 ][ 3 ] = 8
# 80

# %% [markdown]
# Feb 21
# - geoJASON
#     - standard and lists to represent vector: pts, lines, and polygons

# %%
vec = {
"type": "FeatureCollection",#set features, don't change it 
"features": [{#dictionary that represents 1 feature //squarebucket is a list 
"geometry": {#geometry that will showup on screen 
"type": "Point",
"coordinates": [-176.633, 51.883]
},
"type": "Feature",
"properties": {
"wikipedia": "Adak,_Alaska",#attribute table 
"city": "Adak"
},
"id": "Adak"
}]
}

# %%
print(vec['features'][0]['geometry']['coordinates'])#yayy
# Out:
# [-176.633, 51.883]

# %% [markdown]
# Feb 26

# %% [markdown]
# Using geospatial data.
# - open
# - read
# - write
# - close: so the file is not corrupted

# %%
# file_handle = open("file.txt", "w") #w stands for writing, the 2nd parameter is for mode. 
# \n # escape character:

# %%
file_handle = open("file.txt","w") # Open file.txt for writing
# Write some stuff to file.txt
file_handle.write("Hello World of Files.")
file_handle.write("This is another bit of writing.")
file_handle.write("\nNew line and another new line.\n")

for i in range(5):
    file_handle.write("We can even write lines in loops!\n")

file_handle.close() # Close the file

# %%
file_handle = open('file.txt', 'r')

for line in file_handle:
    print(line)

file_handle.close()
# Out:
# Hello World of Files.This is another bit of writing.
#
# New line and another new line.
#
# We can even write lines in loops!
#
# We can even write lines in loops!
#
# We can even write lines in loops!
#
# We can even write lines in loops!
#
# We can even write lines in loops!

# %% [markdown]
# why are we getting the new line characters?
# <blockquote>file_handle.write("\nNew line and another new line.\n")<blockquote>

# %%
print("same thing aas this with a new line\n")
print("double spaced!")
# Out:
# same thing aas this with a new line
#
# double spaced!

# %% [markdown]
# why the empty lines?
# to eliminate the new lines:

# %%
file_handle = open('file.txt', 'r')

for line in file_handle:
    print(line, end = "")#remove the eatra new line


file_handle.close()
# Out:
# Hello World of Files.This is another bit of writing.
# New line and another new line.
# We can even write lines in loops!
# We can even write lines in loops!
# We can even write lines in loops!
# We can even write lines in loops!
# We can even write lines in loops!

# %%
import fiona
fh = fiona.open('cb_2015_27_tract_500k','r')

for f in fh:
    print(f)

print(type(fh))

print(fh[0]['properties'])

fh.close()
# Out:
# ...
# ...
# ...
# <class 'fiona.collection.Collection'>
# ...

# %% [markdown]
# dictionary -> order to conbines lists to dictionary order is preserved

# %%
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'

# %%
import fiona
import folium
import json

m = folium.Map(location = [45.00,-90.87], zoom_start = 6)

for f in fh:

    land area = f'['properties']['ALAND']
    print(land_area)

j = json.dumps(f)
folium.featurs.GeoJson(j).add_to(m)
# Out:
#   Cell In[30], line 9
#     land area = f'['properties']['ALAND']
#                                        ^
# SyntaxError: unterminated string literal (detected at line 9)
